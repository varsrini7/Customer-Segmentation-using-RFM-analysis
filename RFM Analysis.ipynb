# %%
# %matplotlib inline 
import numpy as np 
import pandas as pd    
import warnings
warnings.filterwarnings("ignore")

# %%
df=pd.read_excel('Sales_Data.xlsx')
df.head()
# Out:
#    ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0        10107               30      95.70                2  2871.00
# 1        10121               34      81.35                5  2765.90
# 2        10134               41      94.74                2  3884.34
# 3        10145               45      83.26                6  3746.70
# 4        10168               36      96.66                1  3479.76
#
#    ORDERDATE  DAYS_SINCE_LASTORDER   STATUS  PRODUCTLINE  MSRP PRODUCTCODE  \
# 0 2018-02-24                   828  Shipped  Motorcycles    95    S10_1678
# 1 2018-05-07                   757  Shipped  Motorcycles    95    S10_1678
# 2 2018-07-01                   703  Shipped  Motorcycles    95    S10_1678
# 3 2018-08-25                   649  Shipped  Motorcycles    95    S10_1678
# 4 2018-10-28                   586  Shipped  Motorcycles    95    S10_1678
#
#            CUSTOMERNAME             PHONE                   ADDRESSLINE1  \
# 0     Land of Toys Inc.        2125557818        897 Long Airport Avenue
# 1    Reims Collectables        26.47.1555             59 rue de l'Abbaye
# 2       Lyon Souveniers  +33 1 46 62 7555  27 rue du Colonel Pierre Avia
# 3     Toys4GrownUps.com        6265557265             78934 Hillside Dr.
# 4  Technics Stores Inc.        6505556809              9408 Furth Circle
#
#          CITY POSTALCODE COUNTRY CONTACTLASTNAME CONTACTFIRSTNAME DEALSIZE
# 0         NYC      10022     USA              Yu             Kwai    Small
# 1       Reims      51100  France         Henriot             Paul    Small
# 2       Paris      75508  France        Da Cunha           Daniel   Medium
# 3    Pasadena      90003     USA           Young            Julie   Medium
# 4  Burlingame      94217     USA          Hirano             Juri   Medium

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2747 entries, 0 to 2746
# Data columns (total 20 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   ORDERNUMBER           2747 non-null   int64
#  1   QUANTITYORDERED       2747 non-null   int64
#  2   PRICEEACH             2747 non-null   float64
#  3   ORDERLINENUMBER       2747 non-null   int64
#  4   SALES                 2747 non-null   float64
#  5   ORDERDATE             2747 non-null   datetime64[ns]
#  6   DAYS_SINCE_LASTORDER  2747 non-null   int64
#  7   STATUS                2747 non-null   object
#  8   PRODUCTLINE           2747 non-null   object
#  9   MSRP                  2747 non-null   int64
#  10  PRODUCTCODE           2747 non-null   object
#  11  CUSTOMERNAME          2747 non-null   object
#  12  PHONE                 2747 non-null   object
#  13  ADDRESSLINE1          2747 non-null   object
#  14  CITY                  2747 non-null   object
#  15  POSTALCODE            2747 non-null   object
#  16  COUNTRY               2747 non-null   object
#  17  CONTACTLASTNAME       2747 non-null   object
#  18  CONTACTFIRSTNAME      2747 non-null   object
#  19  DEALSIZE              2747 non-null   object
# dtypes: datetime64[ns](1), float64(2), int64(5), object(12)
# memory usage: 429.3+ KB

# %%
df.describe(include='all')
# Out:
#          ORDERNUMBER  QUANTITYORDERED    PRICEEACH  ORDERLINENUMBER  \
# count    2747.000000      2747.000000  2747.000000      2747.000000
# unique           NaN              NaN          NaN              NaN
# top              NaN              NaN          NaN              NaN
# freq             NaN              NaN          NaN              NaN
# first            NaN              NaN          NaN              NaN
# last             NaN              NaN          NaN              NaN
# mean    10259.761558        35.103021   101.098951         6.491081
# std        91.877521         9.762135    42.042548         4.230544
# min     10100.000000         6.000000    26.880000         1.000000
# 25%     10181.000000        27.000000    68.745000         3.000000
# 50%     10264.000000        35.000000    95.550000         6.000000
# 75%     10334.500000        43.000000   127.100000         9.000000
# max     10425.000000        97.000000   252.870000        18.000000
#
#                SALES            ORDERDATE  DAYS_SINCE_LASTORDER   STATUS  \
# count    2747.000000                 2747           2747.000000     2747
# unique           NaN                  246                   NaN        6
# top              NaN  2018-11-14 00:00:00                   NaN  Shipped
# freq             NaN                   38                   NaN     2541
# first            NaN  2018-01-06 00:00:00                   NaN      NaN
# last             NaN  2020-05-31 00:00:00                   NaN      NaN
# mean     3553.047583                  NaN           1757.085912      NaN
# std      1838.953901                  NaN            819.280576      NaN
# min       482.130000                  NaN             42.000000      NaN
# 25%      2204.350000                  NaN           1077.000000      NaN
# 50%      3184.800000                  NaN           1761.000000      NaN
# 75%      4503.095000                  NaN           2436.500000      NaN
# max     14082.800000                  NaN           3562.000000      NaN
#
#          PRODUCTLINE         MSRP PRODUCTCODE           CUSTOMERNAME  \
# count           2747  2747.000000        2747                   2747
# unique             7          NaN         109                     89
# top     Classic Cars          NaN    S18_3232  Euro Shopping Channel
# freq             949          NaN          51                    259
# first            NaN          NaN         NaN                    NaN
# last             NaN          NaN         NaN                    NaN
# mean             NaN   100.691664         NaN                    NaN
# std              NaN    40.114802         NaN                    NaN
# min              NaN    33.000000         NaN                    NaN
# 25%              NaN    68.000000         NaN                    NaN
# 50%              NaN    99.000000         NaN                    NaN
# 75%              NaN   124.000000         NaN                    NaN
# max              NaN   214.000000         NaN                    NaN
#
#                  PHONE        ADDRESSLINE1    CITY POSTALCODE COUNTRY  \
# count             2747                2747    2747       2747    2747
# unique              88                  89      71         73      19
# top     (91) 555 94 44  C/ Moralzarzal, 86  Madrid      28034     USA
# freq               259                 259     304        259     928
# first              NaN                 NaN     NaN        NaN     NaN
# last               NaN                 NaN     NaN        NaN     NaN
# mean               NaN                 NaN     NaN        NaN     NaN
# std                NaN                 NaN     NaN        NaN     NaN
# min                NaN                 NaN     NaN        NaN     NaN
# 25%                NaN                 NaN     NaN        NaN     NaN
# 50%                NaN                 NaN     NaN        NaN     NaN
# 75%                NaN                 NaN     NaN        NaN     NaN
# max                NaN                 NaN     NaN        NaN     NaN
#
#        CONTACTLASTNAME CONTACTFIRSTNAME DEALSIZE
# count             2747             2747     2747
# unique              76               72        3
# top             Freyre            Diego   Medium
# freq               259              259     1349
# first              NaN              NaN      NaN
# last               NaN              NaN      NaN
# mean               NaN              NaN      NaN
# std                NaN              NaN      NaN
# min                NaN              NaN      NaN
# 25%                NaN              NaN      NaN
# 50%                NaN              NaN      NaN
# 75%                NaN              NaN      NaN
# max                NaN              NaN      NaN

# %%
print("The shape of the data is ",df.shape)
# Out:
# The shape of the data is  (2747, 20)

# %%
print("There are ",df.duplicated().sum()," duplicates in the dataset")
# Out:
# There are  0  duplicates in the dataset

# %%
df_num = df.select_dtypes(exclude = ['object','datetime64[ns]'])

for columns in df_num.columns:
    print('Skewness of {} is'.format(columns), round(df_num[columns].skew(),2))
    print('Kurtosis of {} is'.format(columns), round(df_num[columns].kurt(),2))
# Out:
# Skewness of ORDERNUMBER is -0.01
# Kurtosis of ORDERNUMBER is -1.15
# Skewness of QUANTITYORDERED is 0.37
# Kurtosis of QUANTITYORDERED is 0.44
# Skewness of PRICEEACH is 0.7
# Kurtosis of PRICEEACH is 0.23
# Skewness of ORDERLINENUMBER is 0.58
# Kurtosis of ORDERLINENUMBER is -0.59
# Skewness of SALES is 1.16
# Kurtosis of SALES is 1.77
# Skewness of DAYS_SINCE_LASTORDER is -0.0
# Kurtosis of DAYS_SINCE_LASTORDER is -1.02
# Skewness of MSRP is 0.58
# Kurtosis of MSRP is -0.14

# %%
df1=pd.read_excel('Sales-Binned.xlsx')
pd.set_option('display.max_columns', None)
df1.head()
# Out:
#               CUSTOMERNAME  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER  \
# 0           AV Stores, Co.           1778.0    4645.31             18.0
# 1             Alpha Cognac            687.0    2023.20             12.0
# 2       Amica Models & Co.            843.0    2882.17             17.0
# 3  Anna's Decorations, Ltd           1469.0    4895.51             14.0
# 4        Atelier graphique            270.0     645.67              4.0
#
#    ORDERDATE  DAYS_SINCE_LASTORDER   STATUS   PRODUCTLINE    MSRP  \
# 0       51.0                 421.0  Shipped  Classic Cars  4735.0
# 1       20.0                 675.0  Shipped  Classic Cars  1943.0
# 2       26.0                 328.0  Shipped  Classic Cars  2799.0
# 3       46.0                 131.0  Shipped  Classic Cars  4817.0
# 4        7.0                 312.0  Shipped   Motorcycles   669.0
#
#    PRODUCTCODE           PHONE           ADDRESSLINE1          CITY  \
# 0         51.0  (171) 555-1555      Fauntleroy Circus    Manchester
# 1         20.0      61.77.6555  1 rue Alsace-Lorraine      Toulouse
# 2         26.0     011-4988555    Via Monte Bianco 34        Torino
# 3         46.0    02 9936 8555      201 Miller Street  North Sydney
# 4          7.0      40.32.2555         54, rue Royale        Nantes
#
#   POSTALCODE    COUNTRY CONTACTLASTNAME CONTACTFIRSTNAME DEALSIZE  Recency  \
# 0    EC2 5NT         UK        Ashworth         Victoria   Medium    197.0
# 1      31000     France          Roulet          Annette   Medium     65.0
# 2      10100      Italy         Accorti            Paolo    Large    266.0
# 3       2060  Australia          O'Hara             Anna    Small     84.0
# 4      44000     France         Schmitt           Carine   Medium    189.0
#
#    Frequency   Monetary Recency [Binned] Frequency [Binned] Monetary [Binned]  \
# 0        3.0  157807.81            Bin 3              Bin 2             Bin 4
# 1        3.0   70488.44            Bin 1              Bin 2             Bin 1
# 2        2.0   94117.26            Bin 4              Bin 1             Bin 3
# 3        4.0  153996.13            Bin 2              Bin 4             Bin 4
# 4        3.0   24179.96            Bin 3              Bin 2             Bin 1
#
#    Recency Final  Frequency Final  Monetary Final
# 0              2                2               4
# 1              4                2               1
# 2              1                1               3
# 3              3                4               4
# 4              2                2               1
